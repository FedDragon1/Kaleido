# %%
import dill

MODEL_PATH = "../models/mnist-86p.pkl"

model = dill.load(open(MODEL_PATH, "rb"))
model.summary()
# Out:
# Layer #   Type                          Output Shape                  Param #
# ====================================================================================================
# 1         Input                         (784,)                        0
# 2         Dense                         (16,)                         12560
# 3         LeakyReLU                     (16,)                         0
# 4         Dense                         (16,)                         272
# 5         LeakyReLU                     (16,)                         0
# 6         Dense                         (10,)                         170
# 7         SoftMax                       (10,)                         0
# ====================================================================================================
# Total params:                                                         13002

# %%
import pygame as pg

pg.init()
screen = pg.display.set_mode((280, 280))
pg.display.set_caption("MNIST Example")

drawing = False

while True:
    for event in pg.event.get():
        if event.type == pg.QUIT:
            quit(0)
        elif event.type == pg.KEYDOWN:
            if event.key == pg.K_ESCAPE:
                quit(0)
            elif event.key == pg.K_BACKSPACE:
                screen.fill((0, 0, 0))
        elif event.type == pg.MOUSEBUTTONDOWN:
            drawing = True
        elif event.type == pg.MOUSEBUTTONUP:
            drawing = False
        elif event.type == pg.MOUSEMOTION:
            if drawing:
                x, y = event.pos
                pg.draw.circle(screen, (0, 0, 0), (x, y), 5)
# Out:
# ╭─────────────────────────────── Traceback (most recent call last) ────────────────────────────────╮
# │ in <module>:9                                                                                    │
# │                                                                                                  │
# │    6                                                                                             │
# │    7 drawing = False                                                                             │
# │    8                                                                                             │
# │ ❱  9 while True:                                                                                 │
# │   10 │   for event in pg.event.get():                                                            │
# │   11 │   │   if event.type == pg.QUIT:                                                           │
# │   12 │   │   │   quit(0)                                                                         │
# │                                                                                                  │
# │ ╭─────────────────────────────────────────── locals ───────────────────────────────────────────╮ │
# │ │                          dill = <module 'dill' from                                          │ │
# │ │                                 'C:\\Users\\fedel\\anaconda3\\envs\\deep_learning\\lib\\sit… │ │
# │ │                       drawing = False                                                        │ │
# │ │                         event = <Event(32776-WindowExposed {'window': None})>                │ │
# │ │                          exit = <IPython.core.autocall.ZMQExitAutocall object at             │ │
# │ │                                 0x000002B9E3DAF1C0>                                          │ │
# │ │                   get_ipython = <bound method InteractiveShell.get_ipython of                │ │
# │ │                                 <ipykernel.zmqshell.ZMQInteractiveShell object at            │ │
# │ │                                 0x000002B9E3DACF10>>                                         │ │
# │ │                            In = [                                                            │ │
# │ │                                 │   '',                                                      │ │
# │ │                                 │   'import dill\nimport pygame as pg\n\nMODEL_PATH =        │ │
# │ │                                 "../models/mnist-92p.pkl"\nmodel = '+49,                     │ │
# │ │                                 │   'import dill\nimport pygame as pg\n\nMODEL_PATH =        │ │
# │ │                                 "../models/mnist-86p.pkl"\n\nmodel ='+50,                    │ │
# │ │                                 │   'import dill\n\nMODEL_PATH =                             │ │
# │ │                                 "../models/mnist-86p.pkl"\n\nmodel =                         │ │
# │ │                                 dill.load(open(MODE'+30,                                     │ │
# │ │                                 │   'import pygame as pg\n\npg.init()\nscreen =              │ │
# │ │                                 pg.display.set_mode((280, 280))\npg.displ'+613               │ │
# │ │                                 ]                                                            │ │
# │ │                         model = <Sequential 0x2b9e3f04220 13002 Params>                      │ │
# │ │                    MODEL_PATH = '../models/mnist-86p.pkl'                                    │ │
# │ │                          open = <function open at 0x000002B9E2537D90>                        │ │
# │ │                           Out = {}                                                           │ │
# │ │                            pg = <module 'pygame' from                                        │ │
# │ │                                 'C:\\Users\\fedel\\anaconda3\\envs\\deep_learning\\lib\\sit… │ │
# │ │            pydev_jupyter_vars = <module 'pydev_jupyter_vars' from                            │ │
# │ │                                 'C:\\Users\\fedel\\AppData\\Local\\JetBrains\\Toolbox\\apps… │ │
# │ │                          quit = <IPython.core.autocall.ZMQExitAutocall object at             │ │
# │ │                                 0x000002B9E3DAF1C0>                                          │ │
# │ │ remove_imported_pydev_package = <function remove_imported_pydev_package at                   │ │
# │ │                                 0x000002B9EAAD6440>                                          │ │
# │ │                        screen = <Surface(280x280x32 SW)>                                     │ │
# │ │                           sys = <module 'sys' (built-in)>                                    │ │
# │ ╰──────────────────────────────────────────────────────────────────────────────────────────────╯ │
# ╰──────────────────────────────────────────────────────────────────────────────────────────────────╯
# KeyboardInterrupt
